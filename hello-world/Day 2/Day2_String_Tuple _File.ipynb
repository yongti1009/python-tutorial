# %% [markdown]
# # Part 1 ：String（字串處理）
# ### 字串是 Data Science 最常見的「原始資料格式」。

# %%
text = "Data Science is awesome."
print(text.upper()) # ___.upper() 全部變成大寫
print(text.lower()) # ___.lower() 全部變成小寫

words = text.split() # ___.split() 切成list
print(words)

#replace() 替換字詞
text = "I love Java."
new_text = text.replace("Java", "Python")
print(new_text)
# Out:
# DATA SCIENCE IS AWESOME.
# data science is awesome.
# ['Data', 'Science', 'is', 'awesome.']
# I love Python.

# %% [markdown]
# # #練習1

# %%
sentence = "I love data science."
print(sentence.upper())
new_sentence = sentence.replace("data", "AI")
print(new_sentence)

words = sentence.split()
print(words)
# Out:
# I LOVE DATA SCIENCE.
# I love AI science.
# ['I', 'love', 'data', 'science.']

# %% [markdown]
# # Part 2：Tuple（理解即可）
# ### Tuple = 不能修改的 list

# %%
coordinate = (3, 5)

#取值
print(coordinate[0])
print(coordinate[1])

#解包
x, y = coordinate
print(x)
print(y)
# Out:
# 3
# 5
# 3
# 5

# %% [markdown]
# # #練習2

# %%
point = (10, 20)
x , y = point
print(x)
print(y)
# Out:
# 10
# 20

# %% [markdown]
# # Part 3：File（檔案操作）
# ### Data Science 核心能力之一。

# %%
#write寫入檔案
with open("data.txt", "w") as f:
    f.write("Hello Data Science")

# a (追加)
with open("data.txt", "a") as f:
    f.write("\nNew line")

# %%
#read(讀取檔案)
with open("data.txt", "r") as f:
    content = f.read()

print(content)
# Out:
# Hello Data Science
# New line

# %% [markdown]
# # #練習3

# %%
with open("notes.txt", "w") as f:
    f.write("I am learning Python.")

with open("notes.txt", "r") as f:
    content = f.read()

print(content)
# Out:
# I am learning Python.

# %% [markdown]
# # Part 4：文字清理 Mini Project

# %%
text = "I love Python, PYTHON is great, python!"
text = text.lower()
text = text.replace("python", "data science")
with open("clean.txt", "w") as f:
    f.write (text)

with open("clean.txt", "r") as f:
    content = f.read()

print(content)
# Out:
# i love data science, data science is great, data science!

# %%
#Part 5：String + split（進階應用）
sentence = "apple, banana, orange"
fruits = sentence.split(",")
print(fruits)
# Out:
# ['apple', ' banana', ' orange']

# %%
#練習四
data = "Tom:85,Mary:92,John:78"
scores = data.split(",")
print(scores)
# Out:
# ['Tom:85', 'Mary:92', 'John:78']

# %%
#Part 6：綜合練習（Data Cleaning）
raw = " Data Science is FUN!!! "
#所有string method可以用"."串在一起
words = raw.strip().lower().replace("!!!", "").split()

print(words)
# Out:
# ['data', 'science', 'is', 'fun']

# %%
#Project1:文字分析器
sentence = "Data Science is amazing and Data is powerful"
words = sentence.lower().split()
print(f"總共有{len(words)}個單字")

max_len = 0
longest = []
for w in words:
    if len(w) > max_len:
        max_len = len(w)
        longest = [w]
    
    elif len(w) == max_len:
        longest.append(w)


with open("project2.txt", "w", encoding="utf-8") as f:
    f.write("最長單字："+", ".join(longest))

with open("project2.txt", "r", encoding="utf-8") as f:
    content = f.read()
print(content)
# Out:
# 總共有8個單字
# 最長單字：powerful

# %%
#Project 2 :簡易日誌系統
log = "user login success"
with open("log.txt","w") as f:
    f.write(log)

with open("log.txt", "r") as f:
    content = f.read().lower()

with open("log.txt", "w") as f:
    f.write(content)

# %%
#Project 3:進階挑戰
raw = " Python, JAVA, C++, Python, java "
raw = raw.strip().lower().replace(",","").split()
print(raw)
print(f"共有{len(raw)}個單字")

max_len = 0
longest = []
for r in raw:
    if len(r) > max_len:
        max_len = len(r)
        longest = [r]
    elif len(r) == max_len:
        longest.append(r)
print("最長單字:"+",".join(set(longest))) #set() 重複的單字只會記錄一次

with open("language.txt","w", encoding="utf-8") as f:
    f.write(f"共有{len(raw)}個單字\n")
    f.write("最長單字："+", ".join(set(longest)))
# Out:
# ['python', 'java', 'c++', 'python', 'java']
# 共有5個單字
# 最長單字:python

# %%
#更進階的 Python 寫法（Day 3 會學）
raw = " Python, JAVA, C++, Python, java "
words = raw.strip().lower().replace(",", "").split()

max_len = max(len(word) for word in words)
longest = [word for word in words if len(word) == max_len]

print(f"共有 {len(words)} 個單字")
print("最長單字：", ", ".join(set(longest)))
# Out:
# 共有 5 個單字
# 最長單字： python

# %%
#Project 4：大小寫轉換器
text = "Data SCience"
print(text.upper())
print(text.lower())
# Out:
# DATA SCIENCE
# data science

# %%
#Project 5：單字切割器
sentence = "apple banana orange grape"
print(sentence.split())
print(len(sentence.split()))
# Out:
# ['apple', 'banana', 'orange', 'grape']
# 4

# %%
#Project 6：文字取代器 
text = "I love Java"
print(text.replace("Java", "Python"))
# Out:
# I love Python

# %%
#Project 7：文字清理器
raw = " Data Science is FUN!!! "
print(raw.strip().lower().replace("!!!",""))
# Out:
# data science is fun

# %%
#Project 8：最長單字搜尋
sentence = "Python is powerful and amazing"
words = sentence.split()
max_len = max(len(word) for word in words)
longest = [word for word in words if len(word) == max_len]

print(",".join(set(longest)))
# Out:
# powerful

# %%
#Project 9：Tuple 座標系統
point = (10, 20)
x, y = point
print(x)
print(y)
point2 = (30, 50)
x2, y2 = point2
print(f"x差值 = {abs(x-x2)}") #abs() 絕對值
print(f"y差值 = {abs(y-y2)}")
# Out:
# 10
# 20
# x差值 = 20
# y差值 = 30

# %%
#Project 10：日記寫入系統 
message = "Today I learned Python"
with open("diary.txt", "w") as f:
    f.write(message)

with open("diary.txt", "r") as f:
    content = f.read()

print(content)
# Out:
# Today I learned Python

# %%
#Project 11：簡易 Log 系統
log1 = "User login"
log2 = "Download success"
log3 = "Logout"

with open("login.txt", "w") as f:
    f.write(f"{log1}")
    f.write(f"\n{log2}")
    f.write(f"\n{log3}")

with open("login.txt", "r") as f:
    content = f.read()
print(content)
# Out:
# User login
# Download success
# Logout

# %%
#Project 12：文字分析器
sentence = "Data Science is amazing and Data is powerful"
words = sentence.lower().split()

max_len = max(len(word) for word in words)
longest = [word for word in words if len(word) == max_len]

with open("analysis.txt", "w", encoding = "utf-8" ) as f:
    f.write(f"共有{len(words)}個單字")
    f.write(f"\n{",".join(set(longest))}")

# %%
#Project 13：迷你 Data Cleaning 專案
raw_data = " Python, JAVA, C++, Python, java "
clean = raw_data.lower().strip().replace(",", "").split()


max_len = max(len(word) for word in clean )

longest = [word for word in clean if len(word) == max_len]


min_len = min(len(word) for word in clean )
shortest = [word for word in clean if len(word) == min_len] 

with open("language.txt", "w", encoding = "utf-8") as f:
    f.write(f"共有{len(clean)}個單字")
    f.write(f"\n最長單字：{','.join(set(longest))}")
    f.write(f"\n最短單字：{','.join(set(shortest))}")
# Out:
# ['python', 'java', 'c++', 'python', 'java']

# %%
#Project 13：迷你 Data Cleaning 專案
raw_data = " Python, JAVA, C++, Python, java "

clean = raw_data.strip()
clean = clean.replace(",", "")
clean = clean.lower()
clean = clean.split()

print(clean)
# Out:
# ['python', 'java', 'c++', 'python', 'java']

# %%
#Bonus Project：Data Scientist 版文字統計器
sentence = "Python Python Data Science AI AI AI"
#要用到dictionary
clean = sentence.lower().split()

#設計一個空的dictionary = { word(key) : count(value), } 
count_dict = {}
#逐一統計每個單字 for迴圈
for word in clean:
    if word in count_dict:
        count_dict[word] += 1
    else:
        count_dict[word] = 1

#印出結果
for word, count in count_dict.items(): #___.items()同時取key和value
    print(f"{word} : {count}")

max_appear = max(count_dict[word] for word in clean)
most = [word for word in clean if count_dict[word] == max_appear]
print(f"出現最多次的單字：{','.join(set(most))}\n出現次數：{max_appear}")
# Out:
# python : 2
# data : 1
# science : 1
# ai : 3
# 出現最多次的單字：ai
# 出現次數：3

# %%
#進階版
sentence = "Python Python Data Science AI AI AI"

words = sentence.lower().split()

count_dict = {}

for word in words:
    count_dict[word] = count_dict.get(word, 0) + 1

print(count_dict)

max_appear = max(count_dict[word] for word in words)
most = [word for word in words if count_dict[word] == max_appear]
print(max_appear)
print(",".join(set(most)))
# Out:
# {'python': 2, 'data': 1, 'science': 1, 'ai': 3}
# 3
# ai
